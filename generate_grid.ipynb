# %%
import numpy as np
import geopandas as gpd
from shapely.geometry import box
from shapely.ops import unary_union
from rasterstats import zonal_stats
import rasterio
from rasterio.mask import mask
import glob
import os
import pandas as pd

# %%
CELL_SIZE = 1000  # metres
CELL_AREA_M2 = CELL_SIZE ** 2
CELL_AREA_KM2 = CELL_AREA_M2 / 1e6

WATERCOURSE = "data/watercourse/Watercourse-rough.shp"
ELEVATION = "data/elevation.tif"
IMPERVIOUS = "data/impervious.tif"
HISTORIC_FLOOD = "data/historic_flood_map/Historic_Flood_MapPolygon.shp"
FLOOD_LAYERS = "data/flood_risk/*/*.shp"
BUILDINGS = "data/buildings/buildings.shp"
EDUCATION = "data/education/education.shp"
EMERGENCY_SERVICES = "data/emergency_service/emergency_service.shp"
HOSPITAL = "data/hospitals/hospitals.shp"
SURFACEWATER = "data/surfacewater_area/surfacewater_area.shp"

LSOA = "data/lsoa/lsoa.shp"

# Residential
RESIDENTIAL = "data/residential/residential/residential.shp"

# Commercial
COMMERCIAL = "data/commercial/commercial/commercial.shp"
RETAIL = "data/commercial/retail/retail.shp"

# Industrial
INDUSTRIAL = "data/industrial/industrial/industrial.shp"
LANDFILL = "data/industrial/landfill/landfill.shp"

# Infrastructure
ELECTRICITY = "data/infrastructure/electricity/electricity_transmission.shp"

# Agriculture
FARMLAND = "data/agriculture/farmland/farmland.shp"
FARMYARD = "data/agriculture/farmyard/farmyard.shp"
MEADOW = "data/agriculture/meadow/meadow.shp"
ORCHARD = "data/agriculture/orchard/orchard.shp"

# Transport
ROAD = "data/transport/road/road.shp"
RAILWAY = "data/transport/railway/railway_tracks.shp"

BOUNDARY = "GM_shapefile/CAUTH_MAY_2025_EN_BSC.shp"

OUTPUT = "data/grid/grid.shp"

RISK_SCORES = {
    "Very Low": 0.0005, # (0 + 0.1)/2 
    "Low": 0.00055, # (0.1 + 1)/2
    "Medium": 0.0215, # (1 + 3.3)/2
    "High": 0.033 # (3.3 + 3.3)/2
}

FILE_DEPTH = {
    "merged_rofsw_4bandPolygon.shp": 0.0,
    "merged_rofsw_4band_0_2m_depthPolygon.shp": 0.2,
    "merged_rofsw_4band_0_3m_depthPolygon.shp": 0.3,
    "merged_rofsw_4band_0_6m_depthPolygon.shp": 0.6,
    "merged_rofsw_4band_0_9m_depthPolygon.shp": 0.9,
    "merged_rofsw_4band_1_2m_depthPolygon.shp": 1.2
}

BREAKS = [0, 0.2, 0.3, 0.6, 0.9, 1.2]

# %%
def build_grid(boundary):
    minx, miny, maxx, maxy = boundary.total_bounds

    xs = np.arange(minx, maxx, CELL_SIZE)
    ys = np.arange(miny, maxy, CELL_SIZE)

    grid = gpd.GeoDataFrame(
        geometry=[box(x, y, x + CELL_SIZE, y + CELL_SIZE) for x in xs for y in ys],
        crs="EPSG:27700"
    )

    grid = grid[grid.geometry.within(boundary.geometry.union_all())]
    grid["cell_id"] = grid.index
    return grid

def line_density(grid, lines, colname, cell_size):
    all_lines = pd.concat(lines)
    grid[colname] = 0.0
    cell_area_km2 = (cell_size * cell_size) / 1e6  # km²
    for i, cell in grid.geometry.items():
        inter = all_lines.geometry.intersection(cell)
        length_m = sum(geom.length for geom in inter if not geom.is_empty)
        grid.at[i, colname] = (length_m / 1000) / cell_area_km2

def zonal_density(grid, targets, colname):
    # Union all target polygons into one geometry
    all_geometries = pd.concat(targets).geometry
    unioned = unary_union(all_geometries)

    # Clip unioned geometry to each cell and compute density
    def cell_density(cell_geom):
        cell_area = cell_geom.area
        if cell_area == 0:
            return 0.0
        clipped_area = unioned.intersection(cell_geom).area
        return clipped_area / cell_area

    grid[colname] = grid.geometry.apply(cell_density)

def nearest_distance(grid, targets, colname, km=True):
    centroids = grid.copy()
    centroids["geometry"] = centroids.geometry.centroid

    nearest = gpd.sjoin_nearest(
        centroids,
        targets[["geometry"]],
        how="left",
        distance_col=colname
    )

    dist = nearest.groupby(nearest.index)[colname].first()
    if km:
        dist = dist / 1000

    grid[colname] = dist

def zonal_mean(grid, raster_path, colname):
    stats = zonal_stats(
        grid.geometry,
        raster_path,
        stats="mean",
        nodata=0
    )
    grid[colname] = [s["mean"] for s in stats]

def impervious_surface_frac(grid, raster_path, colname):
    grid[colname] = np.nan
    with rasterio.open(raster_path) as src:
        for i, cell in grid.iterrows():
            out_image, _ = mask(src, [cell.geometry], crop=True)
            out_data = out_image[0]
            total_pixels = out_data.size
            if total_pixels > 0:
                impervious_pixels = np.count_nonzero(out_data != 0)
                grid.at[i, colname] = (impervious_pixels / total_pixels)  

def historic_flood_flag(grid, historic):
    inter = gpd.overlay(
        grid[["cell_id", "geometry"]],
        historic,
        how="intersection"
    )
    inter["area"] = inter.geometry.area
    flooded = inter.groupby("cell_id")["area"].sum()

    grid["historic"] = (
        flooded / CELL_AREA_M2 > 0.5
    ).reindex(grid.cell_id).fillna(False).astype(int)

def flood_depth_probs(grid):
    grid["cell_area"] = grid.geometry.area

    def dstr(d):
        return "0p0" if d == 0 else str(d).replace(".", "p")

    # prepare output columns
    for i in range(len(BREAKS) - 1):
        a, b = BREAKS[i], BREAKS[i + 1]
        grid[f"p_{dstr(a)}_{dstr(b)}"] = 0.0

    grid["p_0"] = 0.0
    grid["p_gt_1p2"] = 0.0

    exceedance = {}

    # process flood layers
    for shp_path in glob.glob(FLOOD_LAYERS):
        layer = gpd.read_file(shp_path).to_crs(grid.crs)
        depth = FILE_DEPTH[os.path.basename(shp_path)]

        # precompute weighted area
        layer["weighted_area"] = layer.geometry.area * layer["risk_band"].map(RISK_SCORES)

        # spatial join with grid
        joined = gpd.sjoin(
            layer[["geometry", "weighted_area"]],
            grid[["cell_id", "geometry"]],
            predicate="intersects",
            how="inner"
        )

        # sum weighted areas per cell → exceedance probability
        ex = joined.groupby("cell_id")["weighted_area"].sum().div(grid.set_index("cell_id")["cell_area"])
        exceedance[depth] = ex

    # write exceedance probabilities to grid
    for depth, series in exceedance.items():
        grid[f"ex_{dstr(depth)}"] = grid["cell_id"].map(series).fillna(0.0)

    # compute depth-range probabilities
    grid["p_0"] = 1 - grid["ex_0p0"]

    for i in range(len(BREAKS) - 1):
        a, b = BREAKS[i], BREAKS[i + 1]
        grid[f"p_{dstr(a)}_{dstr(b)}"] = grid[f"ex_{dstr(a)}"] - grid[f"ex_{dstr(b)}"]

    grid["p_gt_1p2"] = grid[f"ex_{dstr(1.2)}"]

    # cleanup intermediate columns
    grid.drop(columns=[c for c in grid.columns if c.startswith("ex_")], inplace=True)

def lsoa_weighted_sum(grid, targets, feature, colname):
    grid['grid_area'] = grid.geometry.area
    intersected = gpd.overlay(grid.reset_index(), targets[[feature, 'geometry']], how='intersection')
    intersected['frac'] = intersected.geometry.area / intersected['grid_area']
    intersected['weighted'] = intersected[feature] * intersected['frac']
    result = intersected.groupby('index')['weighted'].sum()
    grid[colname] = result

    grid.drop(columns=['grid_area'], inplace=True)

# %%
# LOAD DATA
print("Loading data...")

water = gpd.read_file(WATERCOURSE).set_crs(epsg=27700, allow_override=True)
historic = gpd.read_file(HISTORIC_FLOOD).set_crs(epsg=27700, allow_override=True)
buildings = gpd.read_file(BUILDINGS).set_crs(epsg=27700, allow_override=True)
education = gpd.read_file(EDUCATION).set_crs(epsg=27700, allow_override=True)
emergency = gpd.read_file(EMERGENCY_SERVICES).set_crs(epsg=27700, allow_override=True)
hospital = gpd.read_file(HOSPITAL).set_crs(epsg=27700, allow_override=True)
surfacewater = gpd.read_file(SURFACEWATER).set_crs(epsg=27700, allow_override=True)

residential = gpd.read_file(RESIDENTIAL).set_crs(epsg=27700, allow_override=True)

commercial = gpd.read_file(COMMERCIAL).set_crs(epsg=27700, allow_override=True)
retail = gpd.read_file(RETAIL).set_crs(epsg=27700, allow_override=True)

industrial = gpd.read_file(INDUSTRIAL).set_crs(epsg=27700, allow_override=True)
landfill = gpd.read_file(LANDFILL).set_crs(epsg=27700, allow_override=True)

electricity = gpd.read_file(ELECTRICITY).set_crs(epsg=27700, allow_override=True)

farmland = gpd.read_file(FARMLAND).set_crs(epsg=27700, allow_override=True)
farmyard = gpd.read_file(FARMYARD).set_crs(epsg=27700, allow_override=True)
meadow = gpd.read_file(MEADOW).set_crs(epsg=27700, allow_override=True)
orchard = gpd.read_file(ORCHARD).set_crs(epsg=27700, allow_override=True)

road = gpd.read_file(ROAD).set_crs(epsg=27700, allow_override=True)
railway = gpd.read_file(RAILWAY).set_crs(epsg=27700, allow_override=True)

lsoa = gpd.read_file(LSOA).set_crs(epsg=27700, allow_override=True)
lsoa = lsoa.set_crs(epsg=3857, allow_override=True).to_crs(epsg=27700)

boundary = gpd.read_file(BOUNDARY).set_crs(epsg=27700, allow_override=True)

# %%
# GRID
print("Building grid...")
grid = build_grid(boundary)

# %%
# LSOA WEIGHTED SUM
print("Calculating index multiple deprivation decile...")
lsoa_weighted_sum(grid, lsoa, "IMDDecil", "deprived")

print("Calculating population density...")
lsoa_weighted_sum(grid, lsoa, "popden", "popden")

# %%
# ZONAL DENSITIES
print("Calculating surfacewater density...")
zonal_density(grid, [surfacewater], "water_dens")

print("Calculating buildings density...")
zonal_density(grid, [buildings], "buildings")

print("Calculating education density...")
zonal_density(grid, [education], "education")

print("Calculating residential (residential) density...")
zonal_density(grid, [residential], "resident")

print("Calculating commercial (commercial, retail) density...")
zonal_density(grid, [commercial, retail], "commercial")

print("Calculating industrial (industrial, landfill) density...")
zonal_density(grid, [industrial, landfill], "indust")

print("Calculating agriculture (farmland, farmyard, meadow, orchard) density...")
zonal_density(grid, [farmland, farmyard, meadow, orchard], "agri")

# %%
# LINE DENSITIES
print("Calculating infrastructure (electricity) density...")
line_density(grid, [electricity], "infra", CELL_SIZE)

print("Calculating transport (road, railway) density...")
line_density(grid, [road, railway], "transport", CELL_SIZE)

# %%
# NEAREST DISTANCES
print("Calculating nearest watercourse distance...")
nearest_distance(grid, water, "water_dist", km=False)

print("Calculating nearest major road distance...")
major_roads = road[road["function"].isin(["A Road", "Motorway"])]
nearest_distance(grid, major_roads, "road_dist")


print("Calculating nearest hospital distance...")
nearest_distance(grid, hospital, "hospital")

print("Calculating nearest emergency service distance...")
nearest_distance(grid, emergency, "emergency")

# %%
# RASTER FEATURE
print("Calculating elevation...")
zonal_mean(grid, ELEVATION, "elevation")

# %%
# IMPERVIOUS SURFACE
print("Calculating impervious fraction...")
impervious_surface_frac(grid, IMPERVIOUS, "impervious")

# %%
# HISTORIC FLOOD
print("Calculating historic flood flag...")
historic_flood_flag(grid, historic)

# %%
# FLOOD DEPTH PROBABILITIES
print("Calculating flood depth probabilities...")
flood_depth_probs(grid)

# %%
print(grid.head())

# %%
# SAVE OUTPUT
cols = [
    "water_dens", "water_dist", "elevation",
    "impervious", "historic", "road_dist", "hospital", 
    "emergency", "buildings", "education",
    "popden", "deprived",
    "resident", "commercial", "indust", "infra", "agri", "transport",
    "p_0", "p_0p0_0p2", "p_0p2_0p3", "p_0p3_0p6",
    "p_0p6_0p9", "p_0p9_1p2", "p_gt_1p2",
    "geometry"
]

grid[cols].to_file(OUTPUT)

# %%
# Visualisation
import matplotlib.pyplot as plt
import geopandas as gpd

grid = gpd.read_file(OUTPUT)
cols = grid.select_dtypes(include="number").columns
fig, axes = plt.subplots(nrows=len(cols)//3 + 1, ncols=3, figsize=(18, 6*len(cols)//3))
axes = axes.flatten()

for i, col in enumerate(cols):
    grid.plot(column=col, cmap="viridis", legend=True, ax=axes[i])
    axes[i].set_title(col)
    axes[i].axis("off")

plt.tight_layout()
plt.show()
